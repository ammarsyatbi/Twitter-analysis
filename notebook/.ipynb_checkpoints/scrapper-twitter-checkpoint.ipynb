# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json
import sqlite3
import sys

# %%
ckey=%env API_KEY
csecret=%env API_SECRET_KEY
atoken=%env ACCESS_TOKEN
asecret= %env ACCESS_TOKEN_SECRET

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
api = tweepy.API(auth)

# %%
conn = sqlite3.connect('../data/streamingscrap.sqlite')
conn.text_factory = str
cur = conn.cursor()

# %%
class listener(StreamListener):

    def on_data(self, data):

        all_data = json.loads(data)
        tweet = all_data["text"]
        username = all_data["user"]["screen_name"]
        language = all_data["lang"]
        location = all_data["user"]["location"]
        twDate = all_data['created_at']
        status = all_data['status']

#         cur.execute('INSERT OR IGNORE INTO Tweets (tweet, username, language, location, twDate) VALUES (?, ?, ?, ?, ?)', (tweet, username, language, location, twDate) )

#         conn.commit()

        print(username,tweet, language, location, twDate,status)

        return True

    def on_error(self, status):
        print(status)
        if status == 420:
            # returning False in on_data disconnects the stream
            return False

# %%
#cur.execute('''DROP TABLE IF EXISTS Tweets ''')
# cur.execute('''CREATE TABLE IF NOT EXISTS Tweets (id INTEGER PRIMARY KEY, tweet TEXT, username Text, language Text, location Text, twDate Text)''')


twitterStream = Stream(auth, listener())

#Stream by name
streaming_screen_name="MarStebi"
twitterStream.filter(follow=[str(api.get_user(screen_name = streaming_screen_name).id)])
# twitterStream.filter(track=['lol'], , is_async=True)
# cur.close()
# Out:
# ('MarStebi', 'So many anime so little time', 'en', None, 'Tue Oct 29 18:51:37 +0000 2019')

# %%
def on_status(status):
    if hasattr(status, "retweeted_status"):  # Check if Retweet
        try:
            print(status.retweeted_status.extended_tweet["full_text"])
        except AttributeError:
            print(status.retweeted_status.text)
    else:
        try:
            print(status.extended_tweet["full_text"])
        except AttributeError:
            print(status.text)

# %%
for status in tweepy.Cursor(api.user_timeline, id="izzatamar").items(200):
    on_status(status)
# Out:
# Stayback v29.3c
# Im surprised that i havent been disciplined or anything after fucking up so much
# Hi guys, kalau ada sesiapa interested nak rent area bukit raja pls inform ya!! Boleh check out link below 😁😁 help t… https://t.co/Gc5aiiU9O5
# @azmieraishak Hm member semua ada tempat tinggal la da kerja. Tolong rt je lah ye
# Ayat paling scam selalu aku dengar. https://t.co/QhG53XuORF
# @azmieraishak Akak unprivate sebab rasa tweet ni boleh pergi jauh ke
# 38 out of 510 files https://t.co/hpBARSXSeZ
# My heart 😭
#
# "When a soccer player's hijab started falling off to reveal her hair, her opponents gathered around to… https://t.co/MWbzwtEUJ4
# @nramnizakaria @fendifaizal Tak sekolah la kalau tak ada 🤪
# @nramnizakaria @fendifaizal Cakap sorang ketuwwwww
# HAHAHAHAHAHAHAHAHAHAHAHHAHAHAAHAHAAHHAHAHAAHAHAH FAK https://t.co/r5d1jGscXo
# the only thing that brings me joy anymore is the colorblind guy on tik tok who sorts m&amp;ms https://t.co/swddmvgrYz
# ...
